# %%
import pandas as pd
import numpy as numpy
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('covid19_italy_region.csv')
data
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 0        0  2020-02-24T18:00:00     ITA          13        Abruzzo  42.351222
# 1        1  2020-02-24T18:00:00     ITA          17     Basilicata  40.639471
# 2        2  2020-02-24T18:00:00     ITA          21   P.A. Bolzano  46.499335
# 3        3  2020-02-24T18:00:00     ITA          18       Calabria  38.905976
# 4        4  2020-02-24T18:00:00     ITA          15       Campania  40.839566
# ...    ...                  ...     ...         ...            ...        ...
# 1927  1927  2020-05-25T17:00:00     ITA           9        Toscana  43.769231
# 1928  1928  2020-05-25T17:00:00     ITA          22    P.A. Trento  46.068935
# 1929  1929  2020-05-25T17:00:00     ITA          10         Umbria  43.106758
# 1930  1930  2020-05-25T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 1931  1931  2020-05-25T17:00:00     ITA           5         Veneto  45.434905
#
# ...

# %%
data.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 1927  1927  2020-05-25T17:00:00     ITA           9        Toscana  43.769231
# 1928  1928  2020-05-25T17:00:00     ITA          22    P.A. Trento  46.068935
# 1929  1929  2020-05-25T17:00:00     ITA          10         Umbria  43.106758
# 1930  1930  2020-05-25T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 1931  1931  2020-05-25T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 1927  11.255889                   152                     37
# 1928  11.121231                    27                      4
# 1929  12.388247                    15                      2
# 1930   7.320149                    19                      1
# 1931  12.338452                   179                     10
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  1932.000000  1932.000000  1932.000000  1932.000000
# mean    965.500000    11.857143    43.046293    12.225955
# std     557.864679     6.275423     2.489425     2.659636
# min       0.000000     1.000000    38.115697     7.320149
# 25%     482.750000     7.000000    41.125596    11.121231
# 50%     965.500000    12.000000    43.616760    12.388247
# 75%    1448.250000    17.000000    45.434905    13.768136
# max    1931.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           1932.000000            1932.000000                1932.000000
# mean             764.656832              90.902692                 855.559524
# std             1751.653453             185.534306                1931.023607
# min                0.000000               0.000000                   0.000000
# ...

# %%
##RELATING TH EVARIBLES WITH SCATTER PLOT

# %%
sns.lineplot(x="TotalPositiveCases",y="Deaths",hue='Recovered',data=data)

# %%
sns.lineplot(x="TotalPositiveCases",y="Recovered",data=data)

# %%
sns.lineplot(x="IntensiveCarePatients",y="CurrentPositiveCases",data=data)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.lineplot(x='HomeConfinement',y='TotalPositiveCases',data=data)
